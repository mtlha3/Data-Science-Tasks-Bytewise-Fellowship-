# %%
import pandas as pd

# %%
dataframe = pd.read_csv('C:/Users/Asennus/Bytewise Fellowship/Assignment 5/Exploratory Data Analysis/train.csv')
dataframe.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Summary statistics for the dataset

# %%
summary_statistics = dataframe.describe(include='all')
summary_statistics
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# # Visualization of Numerical Features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# CREATING NEW COLUMN BY SUMMING SibSp AND Parch
dataframe = pd.DataFrame(dataframe)
dataframe['FamilySize'] = dataframe['SibSp'] + dataframe['Parch'] + 1
dataframe
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# histogram of AGE
plt.figure(figsize=(12,6))
sns.histplot(df['Age'], bins=10, kde=False)
plt.title(f'Histogram of {'Age'}')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# histogram of FARE
plt.figure(figsize=(12,6))
sns.histplot(df['Fare'], bins=10, kde=False)
plt.title(f'Histogram of {'Fare'}')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# histogram of FamilySise
plt.figure(figsize=(12,6))
sns.histplot(dataframe['FamilySize'], bins=10, kde=False)
plt.title(f'Histogram of {'Family Size'}')
plt.xlabel('FamilySize')
plt.ylabel('Count')
plt.show()

# KDE for AGE
plt.figure(figsize=(12, 6))
sns.kdeplot(df['Age'], fill=True)
plt.title(f'KDE Plot of {'Age'}')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# KDE for Fare
plt.figure(figsize=(12, 6))
sns.kdeplot(df['Fare'], fill=True)
plt.title(f'KDE Plot of {'Fare'}')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()

# KDE for FamilySize
plt.figure(figsize=(12, 6))
sns.kdeplot(dataframe['FamilySize'], fill=True)
plt.title(f'KDE Plot of {'FamilySize'}')
plt.xlabel('Family Size')
plt.ylabel('Density')
plt.show()

#Box plot for fare
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['Fare'])
plt.title(f'Box Plot of {'Fare'}')
plt.xlabel('Fare')
plt.show()

#Box plot for Age
plt.figure(figsize=(12, 6))
sns.boxplot(x=df['Age'])
plt.title(f'Box Plot of {'Age'}')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# # FEATURE RELATIONSHIP

# %%
# Scatter plot between 'Fare' and 'Age'
plt.figure(figsize=(12, 6))
sns.scatterplot(x='Age', y='Fare', data=df)
plt.title('Scatter Plot of Fare vs. Age')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
# Heatmap of the correlation matrix
plt.figure(figsize=(10, 6))
numeric_df = df.select_dtypes(include=['float64', 'int64']) # Select only numeric value because name aries an error of not converting string to float
correlation_matrix = numeric_df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap of Correlation Matrix')
plt.show()
